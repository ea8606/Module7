# %%
import openpyxl

# %%
wb = openpyxl.load_workbook('BPM_Automation_Roadmap2 _1612_16Nov.xlsx')

# %%
wb

# %%
type(wb)
# Out:
# openpyxl.workbook.workbook.Workbook

# %%
sheet = wb.get_sheet_by_name('Sync')

# %%
sheet
# Out:
# <Worksheet "Sync">

# %%
PRICE_UPDATES = {'Garlic':3.07,
                'Celery':1.19,
                'Lemon':1.27}

# %%
wb.save('produceSales.xlsx')

# %%
wb

# %%
#here you iterate over the rows in the specific column
for row in range(1,sheet.max_row):  
    for column in "ABCD":  #Here you can add or reduce the columns
        cell_name = "{}{}".format(column, row)
        sheet[cell_name].value # the value of the specific cell
        print(cell_name,sheet[cell_name].value)
# Out:
# A1 PRODUCE
# B1 COST PER POUND
# C1 POUNDS SOLD
# D1 TOTAL
# A2 Potatoes
# B2 0.86
# C2 21.6
# D2 =ROUND(B2*C2,2)
# A3 Okra
# B3 2.26
# C3 38.6
# D3 =ROUND(B3*C3,2)
# A4 Fava beans
# B4 2.69
# C4 32.800000000000004
# D4 =ROUND(B4*C4,2)
# A5 Watermelon
# B5 0.66
# C5 27.3
# D5 =ROUND(B5*C5,2)
# A6 Garlic
# B6 1.19
# C6 4.9
# D6 =ROUND(B6*C6,2)
# A7 Parsnips
# B7 2.27
# C7 1.1
# D7 =ROUND(B7*C7,2)
# A8 Asparagus
# B8 2.49
# C8 37.9
# D8 =ROUND(B8*C8,2)
# A9 Avocados
# B9 3.23
# C9 9.200000000000001
# D9 =ROUND(B9*C9,2)
# A10 Celery
# B10 3.07
# C10 28.900000000000002
# D10 =ROUND(B10*C10,2)
# A11 Okra
# B11 2.26
# C11 40
# D11 =ROUND(B11*C11,2)
# A12 Spinach
# B12 4.12
# C12 30
# D12 =ROUND(B12*C12,2)
# A13 Cucumber
# B13 1.07
# C13 36
# D13 =ROUND(B13*C13,2)
# A14 Apricots
# B14 3.71
# C14 29.400000000000002
# D14 =ROUND(B14*C14,2)
# A15 Okra
# B15 2.26
# C15 9.5
# D15 =ROUND(B15*C15,2)
# A16 Fava beans
# B16 2.69
# C16 5.300000000000001
# D16 =ROUND(B16*C16,2)
# A17 Watermelon
# ...

# %%
exit()

# %%
class Critter():
    def __init__(self, name):
        print("in name init")
    def __init__(self, name, name1):
        print("in name, name1 init")

# %% [raw]
# crit1 = Critter("joe)

# %%
crit1 = Critter("joe")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-2bfd2aa7a8e5> in <module>()
# ----> 1 crit1 = Critter("joe")
#
# TypeError: __init__() missing 1 required positional argument: 'name1'
